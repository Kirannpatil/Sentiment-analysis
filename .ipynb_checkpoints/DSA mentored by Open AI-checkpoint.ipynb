# %% [markdown]
# """I interacted with GPT and it advised me to go for following DSA for data science.
#
# You don’t need hardcore Competitive Programming, but:
#
# Solve 1–2 problems daily on LeetCode / HackerRank
#
# 👉 DSA help improves thinking + code efficience
#
# **Ideal Order to Prepare:**
#
# 1.Hashmaps / Dictionaries:
#
#     Frequency counting
#
#     Grouping & bucketing
#
#     Two-sum style problems
#
#     Handling categorical data efficiently
#
# 2.Arry & List:
#
#     Traversal, insertion, deletion
#
#     Prefix sums, difference arrays
#
#     Sorting (quick, merge, insertion)
#
#     Binary search & variations (lower/upper bound, search in rotated array)
#
# 3.Strings:
#
#     Substring search (naive, KMP basics)
#
#     Palindrome checks
#
#     Anagram problems
#
#     Regex basics (for text cleaning)
#
#     basic sorting/searching (binary search, quicksort logic)
#
# 4.Sliding Window:
#
#     Fixed-size window (max/min sum subarray)
#
#     Variable-size window (longest substring without repeats)
#
#     Applications in time-series & streaming data
#
# 5.Recursion (basic recursion for tree traversal or divide-and-conquer intuition)
#
# 6.Sorting & Searching (Minimal)
#
#     Sorting algorithms (know quicksort/mergesort logic)
#
#     Binary search applications (search space problems)
